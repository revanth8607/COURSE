# %% [markdown]
# <a href="https://colab.research.google.com/github/revanth8607/COURSE/blob/main/Movie-Rating(seaborn).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/content'

# %%
mov = pd.read_csv(r'/content/Movie-Rating.csv')

# %%
mov
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
len(mov)
# Out:
# 559

# %%
mov.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
mov.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
mov.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
mov.columns =  ['Film','Genre','CriticRating','AudienceRating','BudgetMillions','Year']

# %%
mov.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
mov.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
mov['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
mov.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
mov.Film = mov.Film.astype('category')

# %%
mov.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ...,
#                            'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
mov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
mov.Year
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: int64

# %%
mov.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %% [markdown]
# ##**Plotting**

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
j = sns.jointplot( data = mov, x = 'CriticRating', y = 'AudienceRating')

# %%
j = sns.jointplot( data = mov, x = 'CriticRating', y = 'AudienceRating', kind = 'hex')

# %% [markdown]
# ##**Histograms**

# %%
m1 = sns.distplot(mov.AudienceRating)

# %%
sns.set_style('darkgrid')
m2 = sns.distplot(mov.AudienceRating, bins= 15)

# %%
m3 = plt.hist(mov.AudienceRating, bin=15)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-d74cd5c7c749> in <cell line: 1>()
# ----> 1 m3 = plt.hist(mov.AudienceRating, bin=15)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2643         orientation='vertical', rwidth=None, log=False, color=None,
#    2644         label=None, stacked=False, *, data=None, **kwargs):
# -> 2645     return gca().hist(
#    2646         x, bins=bins, range=range, density=density, weights=weights,
#    2647         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
# ...

# %%
# histogram with set style as white
#style - darkgrid, whitegrid, dark, white, ticks

sns.set_style('white')
n1 = plt.hist(mov.AudienceRating, bins = 15)

# %%
n1 = plt.hist(mov.CriticRating, bins = 20)

# %% [markdown]
# ##**Stacked Histograms**

# %%
plt.hist(mov.BudgetMillions, color = 'red')
plt.show()

# %%
plt.hist(mov[mov.Genre == 'Drama'].BudgetMillions, color = 'red')
plt.show()

# %%
mov.Genre.unique()
# Out:
# array(['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance',
#        'Thriller'], dtype=object)

# %%
#histograms overlapped

plt.hist(mov[mov.Genre == 'Action'].BudgetMillions, bins = 20, color = 'red')
plt.hist(mov[mov.Genre == 'Thriller'].BudgetMillions, bins = 20, color = 'green')
plt.hist(mov[mov.Genre == 'Drama'].BudgetMillions, bins = 20, color = 'blue')
plt.show()

# %%
#Stacked histograms
plt.hist([mov[mov.Genre == 'Action'].BudgetMillions,\
mov[mov.Genre == 'Drama'].BudgetMillions, \
mov[mov.Genre == 'Thriller'].BudgetMillions,\
mov[mov.Genre == 'Comedy'].BudgetMillions],
bins = 20, stacked = True)
plt.show()

# %%
vis1 = sns.lmplot(data=mov, x='CriticRating', y='AudienceRating',fit_reg=False)

# %%
vis = sns.lmplot(data=mov, x='CriticRating', y='AudienceRating',fit_reg=False, hue = 'Genre')

# %%
vis = sns.lmplot(data = mov, x= 'CriticRating', y = 'AudienceRating', fit_reg= False,hue = 'Genre', aspect = 1)

# %% [markdown]
# ##**Kernel Density Estimate plot**

# %%
k1 = sns.kdeplot(data = mov, x=mov.CriticRating,y=mov.AudienceRating)

# %%
k2 = sns.kdeplot(data = mov, x=mov.CriticRating,y=mov.AudienceRating,shade_lowest=False,cmap='Greens')

# %%
k2 = sns.kdeplot(data = mov,x=mov.CriticRating,y=mov.AudienceRating,shade_lowest=False,cmap='Greens_r')

# %%
sns.set_style('dark')
k1 = sns.kdeplot(data = mov,x=mov.BudgetMillions,y=mov.AudienceRating,shade_lowest=False,cmap='Greens_r')

# %%
k2 = sns.kdeplot(x=mov.BudgetMillions,y=mov.CriticRating)

# %% [markdown]
# ##**Subplots**

# %%
f, ax = plt.subplots(1,2,figsize=(12,6))

# %%
f, axes = plt.subplots(1,2, figsize =(12,6))
k1 = sns.kdeplot(x=mov.BudgetMillions,y=mov.AudienceRating,ax=axes[0])
k2 = sns.kdeplot(x = mov.BudgetMillions,y=mov.CriticRating,ax = axes[1])

# %%
axes
# Out:
# array([<Axes: xlabel='BudgetMillions', ylabel='AudienceRating'>,
#        <Axes: xlabel='BudgetMillions', ylabel='CriticRating'>],
#       dtype=object)

# %% [markdown]
# ##**Box Plots**

# %%
w = sns.boxplot(data = mov,x = 'Genre', y= 'CriticRating')

# %%
w1 = sns.boxplot(data=mov[mov.Genre == 'Drama'], x='Year', y = 'CriticRating')

# %% [markdown]
# ##**Violin plots**

# %%
z = sns.violinplot(data = mov,x='Genre', y = 'CriticRating')

# %%
 z = sns.violinplot(data=mov[mov.Genre == 'Drama'], x='Year', y = 'CriticRating')

# %% [markdown]
# ##**Creating a Facet grid kind of Subplots**

# %%
g = sns.FacetGrid (mov, row = 'Genre', col = 'Year',hue = 'Genre')

# %%
plt.scatter(mov.CriticRating,mov.AudienceRating,color = 'purple')

# %%
g=sns.FacetGrid (mov, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating' )

# %%
g =sns.FacetGrid (mov, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.hist, 'BudgetMillions')

# %%
g =sns.FacetGrid (mov, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s=50, linewidth=0.5,edgecolor='black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating',**kws )

# %% [markdown]
# ##**Building Dashboards**

# %%
sns.set_style('darkgrid')
f, axes = plt.subplots (2,2, figsize = (15,15))

k1 = sns.kdeplot(data = mov,x=mov.BudgetMillions,y=mov.AudienceRating,ax=axes[0,0])
k2 = sns.kdeplot(data = mov,x=mov.BudgetMillions,y=mov.CriticRating,ax = axes[0,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

z = sns.violinplot(data=mov[mov.Genre=='Drama'], x='Year', y = 'CriticRating', ax=axes[1,0])

k4 = sns.kdeplot(data = mov, x=mov.CriticRating,y=mov.AudienceRating,shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])

k4b = sns.kdeplot(x=mov.CriticRating,y= mov.AudienceRating,cmap='Reds',ax = axes[1,1])

plt.show()

# %%
sns.set_style('dark',{'axes.facecolor':'black'})
f, axes = plt.subplots (2,2, figsize = (15,15))

#plot [0,0]
k1 = sns.kdeplot(x=mov.BudgetMillions,y=mov.AudienceRating,shade = True, shade_lowest=True,cmap = 'inferno',ax = axes[0,0])
k1b = sns.kdeplot(x=mov.BudgetMillions,y= mov.AudienceRating, cmap = 'cool',ax = axes[0,0])

#plot [0,1]
k2 = sns.kdeplot(x=mov.BudgetMillions,y=mov.CriticRating,\
                 shade=True, shade_lowest=True, cmap='inferno',\
                 ax = axes[0,1])
k2b = sns.kdeplot(x=mov.BudgetMillions,y=mov.CriticRating,\
                  cmap = 'cool', ax = axes[0,1])

#plot[1,0]
z = sns.violinplot(data=mov[mov.Genre=='Drama'],x='Year', y = 'CriticRating', ax=axes[1,0])

#plot[1,1]
k4 = sns.kdeplot(x=mov.CriticRating,y=mov.AudienceRating,shade = True,shade_lowest=False,cmap='Blues_r',ax=axes[1,1])

k4b = sns.kdeplot(x=mov.CriticRating, y=mov.AudienceRating, cmap='gist_gray_r',ax = axes[1,1])


k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

plt.show()
