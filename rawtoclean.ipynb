# %% [markdown]
# <a href="https://colab.research.google.com/github/revanth8607/COURSE/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/rawtoclean.csv")

# %%
data
# Out:
#    Unnamed: 0                                   Unnamed: 1  Unnamed: 2  \
# 0         NaN                                         ADDR          DT
# 1         NaN  45 rd, kenith street, btm, bangalore 500038  03-04-2022
# 2         NaN            45 rd,  street, hitech, Hd 500038  02-04-2022
# 3         NaN                                          NaN         NaN
# 4         NaN                                          NaN         NaN
# 5         NaN                                          NaN         NaN
# 6         NaN                                          NaN         NaN
#
#   Unnamed: 3 Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0       NAME       time         NaN         NaN         NaN         NaN
# 1        abc    8:30:21         NaN         NaN         NaN         NaN
# 2        dec    5:30:21         NaN         NaN         NaN         NaN
# 3        NaN        NaN         NaN         NaN         NaN         NaN
# ...

# %%
data['ADDR']
# Out:
# 0    45 rd, kenith street, btm, bangalore 500038
# 1              45 rd,  street, hitech, Hd 500038
# Name: ADDR, dtype: object

# %%
data[['hno','street','city','pincode']] = data['ADDR'].str.split(',', expand=True)

# %%
data
# Out:
#                                           ADDR          DT NAME     time  \
# 0  45 rd, kenith street, btm, bangalore 500038  03-04-2022  abc  8.30.21
# 1            45 rd,  street, hitech, Hd 500038  02-04-2022  dec  5.30.21
#
#      hno          street     city            pincode
# 0  45 rd   kenith street      btm   bangalore 500038
# 1  45 rd          street   hitech          Hd 500038

# %%
data[['day','month','year']] = data['DT'].str.split('-',expand = True)

# %%
data
# Out:
#                                           ADDR          DT NAME     time  \
# 0  45 rd, kenith street, btm, bangalore 500038  03-04-2022  abc  8.30.21
# 1            45 rd,  street, hitech, Hd 500038  02-04-2022  dec  5.30.21
#
#      hno          street     city            pincode day month  year
# 0  45 rd   kenith street      btm   bangalore 500038  03    04  2022
# 1  45 rd          street   hitech          Hd 500038  02    04  2022

# %%
data[['hours','minutes','seconds']] = data['time'].str.split('.',expand=True)

# %%
data
# Out:
#   NAME    hno          street     city            pincode day month  year  \
# 0  abc  45 rd   kenith street      btm   bangalore 500038  03    04  2022
# 1  dec  45 rd          street   hitech          Hd 500038  02    04  2022
#
#   hours minutes seconds
# 0     8      30      21
# 1     5      30      21

# %%
data
# Out:
#   NAME    hno          street     city            pincode day month  year  \
# 0  abc  45 rd   kenith street      btm   bangalore 500038  03    04  2022
# 1  dec  45 rd          street   hitech          Hd 500038  02    04  2022
#
#   hours minutes seconds
# 0     8      30      21
# 1     5      30      21
