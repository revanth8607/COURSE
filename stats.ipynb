# %% [markdown]
# <a href="https://colab.research.google.com/github/revanth8607/COURSE/blob/main/Untitled26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/Inc_Exp_Data.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Mthly_HH_Income           50 non-null     int64
#  1   Mthly_HH_Expense          50 non-null     int64
#  2   No_of_Fly_Members         50 non-null     int64
#  3   Emi_or_Rent_Amt           50 non-null     int64
#  4   Annual_HH_Income          50 non-null     int64
#  5   Highest_Qualified_Member  50 non-null     object
#  6   No_of_Earning_Members     50 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 2.9+ KB

# %%
data.head()
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0             5000              8000                  3             2000
# 1             6000              7000                  2             3000
# 2            10000              4500                  2                0
# 3            10000              2000                  1                0
# 4            12500             12000                  2             3000
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0             64200           Under-Graduate                      1
# 1             79920               Illiterate                      1
# 2            112800           Under-Graduate                      1
# 3             97200               Illiterate                      1
# 4            147000                 Graduate                      1

# %%
data.describe()
# Out:
#        Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# count        50.000000         50.000000          50.000000        50.000000
# mean      41558.000000      18818.000000           4.060000      3060.000000
# std       26097.908979      12090.216824           1.517382      6241.434948
# min        5000.000000       2000.000000           1.000000         0.000000
# 25%       23550.000000      10000.000000           3.000000         0.000000
# 50%       35000.000000      15500.000000           4.000000         0.000000
# 75%       50375.000000      25000.000000           5.000000      3500.000000
# max      100000.000000      50000.000000           7.000000     35000.000000
#
#        Annual_HH_Income  No_of_Earning_Members
# count      5.000000e+01              50.000000
# mean       4.900190e+05               1.460000
# std        3.201358e+05               0.734291
# min        6.420000e+04               1.000000
# ...

# %%
data.isna().any()
# Out:
# Mthly_HH_Income             False
# Mthly_HH_Expense            False
# No_of_Fly_Members           False
# Emi_or_Rent_Amt             False
# Annual_HH_Income            False
# Highest_Qualified_Member    False
# No_of_Earning_Members       False
# dtype: bool

# %%
data.isna().any().any()
# Out:
# False

# %%
data.Mthly_HH_Expense.mean()
# Out:
# 18818.0

# %%
data.Mthly_HH_Expense.mode()
# Out:
# 0    25000
# Name: Mthly_HH_Expense, dtype: int64

# %%
expense = pd.crosstab(index=data["Mthly_HH_Expense"], columns="count")
expense.reset_index(inplace=True)
expense[expense['count'] == data.Mthly_HH_Expense.value_counts().max()]
# Out:
# col_0  Mthly_HH_Expense  count
# 18                25000      8

# %%
expense
# Out:
# col_0  Mthly_HH_Expense  count
# 0                  2000      1
# 1                  4500      1
# 2                  5000      1
# 3                  6600      1
# 4                  7000      1
# 5                  8000      3
# 6                  9000      3
# 7                 10000      5
# 8                 10500      1
# 9                 12000      3
# 10                12300      1
# 11                13000      1
# 12                15000      3
# 13                16000      1
# 14                18000      1
# 15                19000      1
# 16                20000      6
# 17                22000      1
# 18                25000      8
# 19                30000      1
# 20                40000      2
# 21                45000      1
# 22                48000      1
# 23                50000      2

# %%
expense
# Out:
# col_0  Mthly_HH_Expense  count
# 0                  2000      1
# 1                  4500      1
# 2                  5000      1
# 3                  6600      1
# 4                  7000      1
# 5                  8000      3
# 6                  9000      3
# 7                 10000      5
# 8                 10500      1
# 9                 12000      3
# 10                12300      1
# 11                13000      1
# 12                15000      3
# 13                16000      1
# 14                18000      1
# 15                19000      1
# 16                20000      6
# 17                22000      1
# 18                25000      8
# 19                30000      1
# 20                40000      2
# 21                45000      1
# 22                48000      1
# 23                50000      2

# %%
data["Highest_Qualified_Member"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
data.plot(x="Mthly_HH_Income", y="Mthly_HH_Expense")
IQR=data["Mthly_HH_Expense"].quantile(0.75)-data["Mthly_HH_Expense"].quantile(0.25)
IQR
# Out:
# 15000.0

# %%
pd.DataFrame(data.iloc[:,0:5].std().to_frame()).T
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0     26097.908979      12090.216824           1.517382      6241.434948
#
#    Annual_HH_Income
# 0     320135.792123

# %%
pd.DataFrame(data.iloc[:,0:4].var().to_frame()).T
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt
# 0     6.811009e+08      1.461733e+08           2.302449     3.895551e+07

# %%
data["Highest_Qualified_Member"].value_counts().to_frame().T
# Out:
#                           Graduate  Under-Graduate  Professional  \
# Highest_Qualified_Member        19              10            10
#
#                           Post-Graduate  Illiterate
# Highest_Qualified_Member              6           5

# %%
data["Highest_Qualified_Member"].value_counts().to_frame().T
# Out:
#                           Graduate  Under-Graduate  Professional  \
# Highest_Qualified_Member        19              10            10
#
#                           Post-Graduate  Illiterate
# Highest_Qualified_Member              6           5

# %%
data["No_of_Earning_Members"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
Coeff_of_var_StockA=10/15
print(Coeff_of_var_StockA)
Coeff_of_var_StockB=5/10
print(Coeff_of_var_StockB)
# Out:
# 0.6666666666666666
# 0.5
