# %% [markdown]
# <a href="https://colab.research.google.com/github/revanth8607/COURSE/blob/main/pca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

# %%
iris = load_iris()
x = iris.data
y = iris.target
x[0:3]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2]])

# %%
pca = PCA(n_components=2)

# %%
x_pca = pca.fit_transform(x)
x_pca[0:5]
# Out:
# array([[-2.68412563,  0.31939725],
#        [-2.71414169, -0.17700123],
#        [-2.88899057, -0.14494943],
#        [-2.74534286, -0.31829898],
#        [-2.72871654,  0.32675451]])

# %%
pca = PCA(n_components=3)
x_pca_3 = pca.fit_transform(x)
x_pca_3[0:5]
x_pca_3.shape
# Out:
# (150, 3)

# %%
sns.scatterplot(x=x_pca[:,0],y=x_pca[:,1],hue=y,palette='viridis',s=50)
plt.title('IRIS')
plt.xlabel('principal component 1')
plt.ylabel('principal component 2')
plt.legend()
plt.show()

# %%
sns.scatterplot(x=x_pca_3[:,0],y=x_pca_3[:,1],hue=y,palette='viridis',s=50)
plt.title('Iris DataSet')
plt.xlabel("principal component 1")
plt.ylabel("principal compoent 2")
plt.legend()
plt.show()
