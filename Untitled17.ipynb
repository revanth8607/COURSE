# %% [markdown]
# <a href="https://colab.research.google.com/github/revanth8607/COURSE/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
movies = pd.read_csv('/content/movie.csv')
tags = pd.read_csv('/content/tag.csv')
rating = pd.read_csv('/content/rating.csv')

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
tags
# Out:
#         userId  movieId            tag            timestamp
# 0           18     4141    Mark Waters  2009-04-24 18:19:40
# 1           65      208      dark hero  2013-05-10 01:41:18
# 2           65      353      dark hero  2013-05-10 01:41:19
# 3           65      521  noir thriller  2013-05-10 01:39:43
# 4           65      592      dark hero  2013-05-10 01:41:18
# ...        ...      ...            ...                  ...
# 465559  138446    55999        dragged  2013-01-23 23:29:32
# 465560  138446    55999  Jason Bateman  2013-01-23 23:29:38
# 465561  138446    55999         quirky  2013-01-23 23:29:38
# 465562  138446    55999            sad  2013-01-23 23:29:32
# 465563  138472      923  rise to power  2007-11-02 21:12:47
#
# [465564 rows x 4 columns]

# %%
rating
# Out:
#         userId  movieId  rating            timestamp
# 0            1        2     3.5  2005-04-02 23:53:47
# 1            1       29     3.5  2005-04-02 23:31:16
# 2            1       32     3.5  2005-04-02 23:33:39
# 3            1       47     3.5  2005-04-02 23:32:07
# 4            1       50     3.5  2005-04-02 23:29:40
# ...        ...      ...     ...                  ...
# 791823    5286      900     4.0  2013-07-16 00:19:51
# 791824    5286      902     3.5  2013-07-16 00:21:27
# 791825    5286      904     5.0  2013-07-16 01:08:33
# 791826    5286      905     3.5  2013-07-16 00:05:35
# 791827    5286      908     5.0    2013-07-16 01:08:
#
# [791828 rows x 4 columns]

# %%
del rating['timestamp']
del tags['timestamp']

# %%
rating.head()
# Out:
#    userId  movieId  rating
# 0       1        2     3.5
# 1       1       29     3.5
# 2       1       32     3.5
# 3       1       47     3.5
# 4       1       50     3.5

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
row = tags.iloc[0]
type(row)
# Out:
# pandas.core.series.Series

# %%
print(row)
# Out:
# userId              18
# movieId           4141
# tag        Mark Waters
# Name: 0, dtype: object

# %%
row.index
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
row['userId']
# Out:
# 18

# %%
'rating' in row
# Out:
# False

# %%
row = row.rename('first')
row.name
# Out:
# 'first'

# %%
tags.index
# Out:
# RangeIndex(start=0, stop=465564, step=1)

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
tags.iloc[[0,5,200]]
# Out:
#      userId  movieId          tag
# 0        18     4141  Mark Waters
# 5        65      668    bollywood
# 200     129    55280  dork people

# %%
rating['rating'].describe()
# Out:
# count    791828.000000
# mean          3.521442
# std           1.052594
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: rating, dtype: float64

# %%
rating.describe()
# Out:
#               userId        movieId         rating
# count  791828.000000  791828.000000  791828.000000
# mean     2668.398837    8776.643596       3.521442
# std      1513.945390   19329.816229       1.052594
# min         1.000000       1.000000       0.500000
# 25%      1350.000000     903.000000       3.000000
# 50%      2706.000000    2145.000000       3.500000
# 75%      3976.000000    4676.000000       4.000000
# max      5286.000000  130642.000000       5.000000

# %%
rating['rating'].mean()
# Out:
# 3.521442156629975

# %%
rating.mean()
# Out:
# userId     2668.398837
# movieId    8776.643596
# rating        3.521442
# dtype: float64

# %%
rating.mean()
# Out:
# userId     2668.398837
# movieId    8776.643596
# rating        3.521442
# dtype: float64

# %%
rating['rating'].min()
# Out:
# 0.5

# %%
rating['rating'].max()
# Out:
# 5.0

# %%
rating['rating'].std()
# Out:
# 1.0525935203018144

# %%
rating['rating'].mode()
# Out:
# 0    4.0
# Name: rating, dtype: float64

# %%
rating.corr()
# Out:
#            userId   movieId    rating
# userId   1.000000  0.010340  0.012851
# movieId  0.010340  1.000000 -0.001486
# rating   0.012851 -0.001486  1.000000

# %%
f = rating['rating']>10
print(f)
f.any()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 791823    False
# 791824    False
# 791825    False
# 791826    False
# 791827    False
# Name: rating, Length: 791828, dtype: bool
# False

# %%
f = rating['rating']>0
f.all()
# Out:
# True

# %%
movies.shape
# Out:
# (27278, 3)

# %%
movies.isnull().any().any()
# Out:
# False

# %%
rating.shape
# Out:
# (791828, 3)

# %%
tags = tags.dropna()
tags
# Out:
#         userId  movieId            tag
# 0           18     4141    Mark Waters
# 1           65      208      dark hero
# 2           65      353      dark hero
# 3           65      521  noir thriller
# 4           65      592      dark hero
# ...        ...      ...            ...
# 465559  138446    55999        dragged
# 465560  138446    55999  Jason Bateman
# 465561  138446    55999         quirky
# 465562  138446    55999            sad
# 465563  138472      923  rise to power
#
# [465548 rows x 3 columns]

# %%
tags.isnull().any().any()
# Out:
# False

# %%
tags.shape
# Out:
# (465548, 3)

# %%
# %matplotlib inline
rating.hist(column = 'rating', figsize=(10,5))
# Out:
# array([[<Axes: title={'center': 'rating'}>]], dtype=object)

# %%
rating.boxplot(column='rating',figsize=(10,5))
# Out:
# <Axes: >

# %%
tags['tag'].head()
# Out:
# 0      Mark Waters
# 1        dark hero
# 2        dark hero
# 3    noir thriller
# 4        dark hero
# Name: tag, dtype: object

# %%
movies[['title','genres']].head()
# Out:
#                                 title  \
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
rating[-10:]
# Out:
#         userId  movieId  rating
# 791818    5286      596     3.5
# 791819    5286      597     3.5
# 791820    5286      780     2.5
# 791821    5286      898     4.0
# 791822    5286      899     5.0
# 791823    5286      900     4.0
# 791824    5286      902     3.5
# 791825    5286      904     5.0
# 791826    5286      905     3.5
# 791827    5286      908     5.0

# %%
tag_counts = tags['tag'].value_counts()
tag_counts[-10:]
# Out:
# missing child                    1
# Ron Moore                        1
# Citizen Kane                     1
# mullet                           1
# biker gang                       1
# Paul Adelstein                   1
# the wig                          1
# killer fish                      1
# genetically modified monsters    1
# topless scene                    1
# Name: tag, dtype: int64

# %%
tag_counts[:10].plot(kind='bar',figsize=(10,5))
# Out:
# <Axes: >
